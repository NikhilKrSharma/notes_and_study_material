# %%
import os

def rename_files_in_directory(directory_path):
    # Get a list of all items in the directory
    items = os.listdir(directory_path)
    
    for item in items:
        old_path = os.path.join(directory_path, item)
        
        # Only rename if it's a file, not a directory
        if os.path.isfile(old_path):
            # Split filename into base and extension
            base_name, extension = os.path.splitext(item)
            # Create the new filename
            # new_filename = f"{base_name}_temp{extension}"
            new_filename = base_name.replace("_temp", "")
            new_path = os.path.join(directory_path, new_filename)
            
            # Rename the file
            os.rename(old_path, new_path)
            print(f"Renamed: {old_path} -> {new_path}")

# %%
rename_files_in_directory(directory_path="/Users/nikhil20.sharma/Library/CloudStorage/GoogleDrive-nikhil.sharma1294@gmail.com/.shortcut-targets-by-id/1hJdN4IVIzv_akIWArIYt52MlRCEbxXvV/its.nikhilksharma/REPOs/notes_and_study_material/quickRevision")
# Out:
# Renamed: /Users/nikhil20.sharma/Library/CloudStorage/GoogleDrive-nikhil.sharma1294@gmail.com/.shortcut-targets-by-id/1hJdN4IVIzv_akIWArIYt52MlRCEbxXvV/its.nikhilksharma/REPOs/notes_and_study_material/quickRevision/multicollinearity.md -> /Users/nikhil20.sharma/Library/CloudStorage/GoogleDrive-nikhil.sharma1294@gmail.com/.shortcut-targets-by-id/1hJdN4IVIzv_akIWArIYt52MlRCEbxXvV/its.nikhilksharma/REPOs/notes_and_study_material/quickRevision/multicollinearity_temp.md
# Renamed: /Users/nikhil20.sharma/Library/CloudStorage/GoogleDrive-nikhil.sharma1294@gmail.com/.shortcut-targets-by-id/1hJdN4IVIzv_akIWArIYt52MlRCEbxXvV/its.nikhilksharma/REPOs/notes_and_study_material/quickRevision/featureSelection.md -> /Users/nikhil20.sharma/Library/CloudStorage/GoogleDrive-nikhil.sharma1294@gmail.com/.shortcut-targets-by-id/1hJdN4IVIzv_akIWArIYt52MlRCEbxXvV/its.nikhilksharma/REPOs/notes_and_study_material/quickRevision/featureSelection_temp.md
# ...
